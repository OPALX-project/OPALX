# %% [markdown]
# # OPAL - OPAL-X comparison

# %% [markdown]
# ## Load the Accelerated.stat file

# %%
import sys
sys.path.append('/psi/home/adelmann/git/pyOPALTools')
import numpy as np
from opal import load_dataset

import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import ipywidgets as widgets
from IPython.display import display
import re
# %matplotlib notebook

# %% [markdown]
# ## Set the plotting style

# %%
from opal.visualization.styles import load_style

load_style('jupyter')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # OPAL and OPALX data directories on Merlin

# %%
opaldir  = '/psi/home/adelmann/git/opal-src-4-opalx-debug/input-files/Drift-1/'
opalxdir = '/psi/home/adelmann/opalx/input-files/'

# %% [markdown]
# # Compare Beamsizes

# %%
opalstat  = load_dataset(opaldir, fname='Drift-1.stat').dataframe
opalxstat = load_dataset(opalxdir, fname='Drift-1.stat').dataframe

opalh5    = load_dataset(opaldir, fname='Drift-1.h5')
opalxh5   = load_dataset(opalxdir, fname='Drift-1.h5')

# %%
print(opalstat[['xpx','ypy','zpz']])
print(opalxstat[['xpx','ypy','zpz']])
# Out:
#         xpx       ypy       zpz
# 0  0.000485  0.002669  0.000039
# 1  0.000486  0.002669  0.000039
# 2  0.000486  0.002669  0.000039
# 3  0.000487  0.002669  0.000039
# 4  0.000488  0.002669  0.000039
# 5  0.000489  0.002669  0.000039
# 6  0.000489  0.002669  0.000039
# 7  0.000490  0.002670  0.000039
# 8  0.000491  0.002670  0.000039
# 9  0.000491  0.002670  0.000039
#         xpx       ypy       zpz
# 0 -0.001277  0.002690  0.003871
# 1 -0.001200  0.002640  0.003851
# 2 -0.001121  0.002589  0.003830
# 3 -0.001040  0.002538  0.003809
# 4 -0.000958  0.002487  0.003788
# 5 -0.000875  0.002435  0.003767
# 6 -0.000792  0.002384  0.003745
# 7 -0.000709  0.002332  0.003724
# 8 -0.000627  0.002280  0.003703
# 9 -0.000546  0.002228  0.003681

# %%
plt.figure(figsize=(15, 10))
f, ax = plt.subplots(1)
ax.set_ylim(ymin=0)
ax.set_ylim(ymax=1e-2)
plt.plot(opalstat['s'],opalstat['rms_x'],label='x OPAL')
plt.plot(opalxstat['s'],opalxstat['rms_x'], label='x OPALX')
plt.plot(opalstat['s'],opalstat['rms_y'],label='y OPAL')
plt.plot(opalxstat['s'],opalxstat['rms_y'], label='y OPALX')
plt.plot(opalstat['s'],opalstat['rms_s'],label='z OPAL')
plt.plot(opalxstat['s'],opalxstat['rms_s'], label='z OPALX')
plt.xlabel('s [m]')
plt.ylabel('rms x [m]')
plt.legend()
plt.show()
